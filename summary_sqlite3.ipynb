# %% [markdown]
# ![image.png](sqlite-sample-database-color.jpg)

# %%
import sqlite3
from sqlite3 import Error


def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def select_tasks(conn, query):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute(query)

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
database = r"C:\Users\User\Documents\python\chinook.db"

# create a database connection
conn = create_connection(database)

# %%
query = '''
    select 
    tmp2.name1, 
    tmp2.name2,  
    g.name as name3 
    from
    genres g
    left join
    (
    select tmp.name as name1, t.name as name2, genreid from
    (
        select p.playlistid, name, trackid from 
        playlists p left join playlist_track pt on p.playlistid = pt.playlistid
        ) tmp left join tracks t on tmp.trackid = t.trackid
    ) tmp2 
    on g.genreid = tmp2.genreid
    '''
select_tasks(conn, query)
# Out:
# ('90’s Music', '(Da Le) Yaleo', 'Rock')
# ('90’s Music', '2 A.M.', 'Rock')
# ('90’s Music', '2 Minutes To Midnight', 'Rock')
# ('90’s Music', '2,000 Man', 'Rock')
# ('90’s Music', '2112 Overture', 'Rock')
# ('90’s Music', 'A Castle Full Of Rascals', 'Rock')
# ('90’s Music', 'A New Flame', 'Rock')
# ('90’s Music', 'A Room At The Heartbreak Hotel', 'Rock')
# ('90’s Music', 'A Touch Away', 'Rock')
# ('90’s Music', 'A Twist In The Tail', 'Rock')
# ('90’s Music', 'A World Without Heroes', 'Rock')
# ('90’s Music', 'Absolute Zero', 'Rock')
# ('90’s Music', 'Acrobat', 'Rock')
# ('90’s Music', 'Action', 'Rock')
# ('90’s Music', 'Afraid To Shoot Strangers', 'Rock')
# ('90’s Music', 'Afraid To Shoot Strangers', 'Rock')
# ('90’s Music', 'Africa Bamba', 'Rock')
# ('90’s Music', 'Alive', 'Rock')
# ('90’s Music', 'All I Really Want', 'Rock')
# ('90’s Music', 'All I Want Is You', 'Rock')
# ('90’s Music', 'Always With Me, Always With You', 'Rock')
# ('90’s Music', 'Amazing', 'Rock')
# ...

# %%
select_tasks(conn, 'select * from tracks')
